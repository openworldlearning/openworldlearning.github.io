# %% [markdown]
# # What is orthogonality?
#
# <b>Author:</b> Audun Skau Hansen <a href="mailto:a.s.hansen@kjemi.uio.no">✉️</a>
#
# The Hylleraas Centre for Quantum Molecular Sciences and
# The Centre for Computing in Science Education,
# 2022
#
# ---

# %% [markdown]
# Words like *independence* and *overlap* is often used

# %%
import braketlab as bk

# %%
p1 = bk.basisbank.get_harmonic_oscillator_function(1)
p2 = bk.basisbank.get_harmonic_oscillator_function(2)
p3 = bk.basisbank.get_harmonic_oscillator_function(3)

p = p1@p2@p3 #outer product

# %%
(p).view()
# Out:
# BraketView(ao=[1], fragment_shader='uniform vec3 user_color;\nuniform float time;\n\nvarying vec2 vUv;\nvaryin…

# %%
import numpy as np
import matplotlib.pyplot as plt 

bins, vals = np.histogram(p3.measure(repetitions = 100000))

plt.plot(bins)
